# %% [markdown]
# # Context
#
# Concrete is one of the most important materials in civil engineering. Concrete's compressive strength is a highly nonlinear function of age and ingredients.
#
# # Business Problem
#
# This is a supervised regression problem. The objective is to accurately predict the strength of steel using various ingredients used in the production of concrete.
#
#
# # Data
#
# The dataset contains 1030 observations accross 8 input variables and an output variable. The variable name, variable type, the measurement unit and a brief description is provided.
#
#   **Name --              Data Type --      Measurement --       Description**
#
# Cement (component 1) -- quantitative -- kg in a m3 mixture -- Input Variable
#
# Blast Furnace Slag (component 2) -- quantitative -- kg in a m3 mixture -- Input Variable
#
# Fly Ash (component 3) -- quantitative -- kg in a m3 mixture -- Input Variable
#
# Water (component 4) -- quantitative -- kg in a m3 mixture -- Input Variable
#
# Superplasticizer (component 5) -- quantitative -- kg in a m3 mixture -- Input Variable
#
# Coarse Aggregate (component 6) -- quantitative -- kg in a m3 mixture -- Input
#
# Fine Aggregate (component 7) -- quantitative -- kg in a m3 mixture -- Input Variable
#
# Age -- quantitative -- Day (1~365) -- Input Variable
#
# Concrete compressive strength -- quantitative -- MPa -- Output Variable|
#
#
# # Acknowledgements
#
# Original Owner and Donor
#
# Prof. I-Cheng Yeh
#
# Department of Information Management
#
# Chung-Hua University
#
# Citation Request:
#
# I-Cheng Yeh, "Modeling of strength of high performance concrete using artificial neural networks," Cement and Concrete Research, Vol. 28, No. 12, pp. 1797-1808 (1998).

# %% [markdown]
# # Importing Libraries & Data

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR, LinearSVR
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from xgboost import XGBRegressor

# %%
df = pd.read_csv(r"C:\Users\Desktop\Data_Science\Datasets\Concrete_Data_Yeh.csv")

# %% [markdown]
# # 1) Exploratory Data Analysis

# %% [markdown]
# # 1.1 Univariate Analysis

# %%
df.isna().sum()
# Out:
# cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cement            1030 non-null   float64
#  1   slag              1030 non-null   float64
#  2   flyash            1030 non-null   float64
#  3   water             1030 non-null   float64
#  4   superplasticizer  1030 non-null   float64
#  5   coarseaggregate   1030 non-null   float64
#  6   fineaggregate     1030 non-null   float64
#  7   age               1030 non-null   int64
#  8   csMPa             1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.describe()
# Out:
#             cement         slag       flyash        water  superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        coarseaggregate  fineaggregate          age        csMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# ...

# %% [markdown]
# All predictors in the dataset are quantitative datatypes. Moreover, there are no missing values in the data. Lets analyse the probability distribution of the variables through a series of univariate density plots.

# %%
# Kernal Density plots to see distribution of variables
variables = list(df.columns[:])
sns.set(style="white") 
plt.figure(figsize = (20 , 20))
independent = variables[:]
for variable in range(9):
    plt.subplot(4, 3, variable + 1)
    sns.kdeplot(df[independent[variable]], shade = True, color="green")
plt.show()

# %% [markdown]
# Most variables do not follow normal distribution. It would be interesting to convert the response variable into a category of 'optimal' and 'suboptimal' in order to detect any interesting patterns between the predictors and the target variable. I'll conisder the observations at the 75th percentile or greater to be good. Additionally I will create another categorical variable out of the response variable with four categories good, better, great and perfect.

# %% [markdown]
# # 1.2 Bivariate Analysis

# %%
# Creating 3 bins out of the response variable.
df['target_cat'] = pd.cut(df.csMPa,
                     bins=[0, 23, 34, 46, 82],
                     labels=["Good", "Better", "Great", "Perfect"])

# %%
# Observations at the 75th percentile (46) are considered optimal. Anything lower than it is suboptimal.
df['target_binary'] = np.where( df.csMPa > 46, 'optimal', 'suboptimal')

# %%
# Barcharts representing good, better, best, perfect compressive strength against mean predictors.
variables = list(df.columns)
independent = variables[0:-2]
sns.set(style="white") 
plt.figure(figsize = (20 , 60))
for variable in range(8):
    plt.subplot(12, 4 , variable + 1)
    sns.barplot(x = df['target_cat'], y = df[independent[variable]],  palette='Set1' )
plt.show()

# %%
# Barcharts representing optimal and suboptimal compressive strength against mean predictors.
sns.set(style="white") 
plt.figure(figsize = (20 , 60))
for variable in range(8):
    plt.subplot(12, 4 , variable + 1)
    sns.barplot(x = df['target_binary'], y =df[independent[variable]],  palette='Set1' )
plt.show()

# %%
# Boxplots of good and suboptimal compressive strength against ingredients.
sns.set(style="white") 
plt.figure(figsize = (20 , 60))
for variable in range(8):
    plt.subplot(15,3 , variable + 1)
    sns.boxplot(x = df['target_binary'], y =df[independent[variable]],  palette='Set1' )
plt.show()

# %%
# Boxplots of good and bad compressive strength against ingredients.
sns.set(style="white") 
plt.figure(figsize = (20 , 60))
for variable in range(9):
    plt.subplot(15,3 , variable + 1)
    sns.boxplot(x = df['target_cat'], y = df[independent[variable]],  palette='Set1' )
plt.show()

# %% [markdown]
# There seem to be some interesting patterns between the ingredients and the strength of the product. Greater quantities of cement and superplasticizer along with lower amounts of water seems to correlate with a stronger product. Lets create a pearsons correlation correlogram to quantitatively detect these associations.

# %%
# Lets make subsets of the independent and dependent variables
X =  df.drop(columns=['csMPa', 'target_cat', 'target_binary'])
y =  df['csMPa']

# %%
# Lets deploy a correlogram for colrrelation
colormap = plt.cm.Blues
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap=colormap, annot=True, linewidths=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The pearsons correlation assumes linearity, homoscedasticity and no outliers. These assumptions are violated for most variables. This may be a potential reason as to why pearsons correlation won't detect nuances between predictors and the independent variables properly. Nonetheless, cement, water, and superplastisizer do seem to be moderately correlated with strength.

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# Some machine learning algorithms require features to be scaled through normalization or standardization. For instance, the K-nearest neighbour algorithm utilizes the euclidean distance and features with different ranges could be problematic. I will now split the dataset into training and testing and then perform standardization which will transform the features to a mean of 0 and sd of 1.

# %%
# Split the dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True, random_state = 43)

# Feature Scaling 
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test =sc.transform(X_test)

# %% [markdown]
# # 3. Predictive Modelling

# %%
# Put models in a dictionary
algorithms = {"KNN": KNeighborsRegressor(),
          "Linear Regression": LinearRegression(), 
          "Ridge Regression": Ridge(),
          "Random Forest": RandomForestRegressor(),
          "SVR RBF": SVR(),
          "Linear SVR": LinearSVR(),
          "Decision Tree":DecisionTreeRegressor(),
          "Adaboost" :AdaBoostRegressor(),
          "Gradient Boosting":GradientBoostingRegressor(),
          "Neural Network": MLPRegressor(max_iter=10000) ,
          "XGBRegressor" : XGBRegressor()}


# Create function to train and test the model
def train_and_test(algorithms, X_train,y_train,X_test,y_test):
    model_scores = {}
    for name, model in algorithms.items():
        model.fit(X_train, y_train)
        print(name + " R2: {:.2f}".format(model.score(X_test, y_test)))


model_scores = train_and_test(algorithms, X_train, y_train, X_test, y_test)
# Out:
# KNN R2: 0.71
# Linear Regression R2: 0.60
# Ridge Regression R2: 0.60
# Random Forest R2: 0.89
# SVR RBF R2: 0.62
# Linear SVR R2: 0.58
# Decision Tree R2: 0.85
# Adaboost R2: 0.77
# Gradient Boosting R2: 0.86
# Neural Network R2: 0.87
# XGBRegressor R2: 0.89

# %% [markdown]
# The non-linear algorithms perform far better than their linear counterparts. Amongst the non-linear models XGBoost seems to outperform all other models. I will now set a grid search and perform hyperparametric tuning to try and further enhance its performance.

# %%
estimator = XGBRegressor()
estimator.fit(X_train, y_train)
print("R2: {:.3f}".format(estimator.score(X_test, y_test)))
# Out:
# R2: 0.885

# %%
param_grid       =      {"learning_rate": (0.05, 0.10, 0.15),
                         "max_depth": [ 3, 4, 5, 6, 8],
                         "min_child_weight": [ 1, 3, 5, 7],
                         "gamma":[ 0.0, 0.1, 0.2],
                         "colsample_bytree":[ 0.3, 0.4]}

optimized_estimator =  GridSearchCV(estimator, param_grid)
optimized_estimator.fit(X_train, y_train)

optimized_estimator.best_params_
for i, j in optimized_estimator.best_params_.items():
    print("\nBest " + str(i) + " parameter: " +  str(j))
# Out:
# Best colsample_bytree parameter: 0.4
#
# Best gamma parameter: 0.2
#
# Best learning_rate parameter: 0.15
#
# Best max_depth parameter: 5
#
# Best min_child_weight parameter: 7

# %%
print("XGBoost R2 after hyperparametric Tuning: {:.5f}".format(optimized_estimator.score(X_test, y_test)))
# Out:
# XGBoost R2 after hyperparametric Tuning: 0.89233

# %% [markdown]
# The model seems to have improved slightly.

# %% [markdown]
# # 4. Conclusion
#
# This notebook performed supervised learning to predict the compressive strength of cement using various psysiochemical ingredients. The tasks carried out in this report inlclude exploratory data analysis through visualizations and statistics, followed by preprocessing, modelling and hyperparametric tuning. The relationship between the predictors and independent variables is highly non linear as non linear models performed notably better than their linear counterparts.
